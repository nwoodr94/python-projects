# %%
iterator = 101

for i in list(range(1, iterator)):
    if (i % 3) == 0 and (i % 5) == 0:
        print(i, "fizzbuzz")
    elif (i % 5) == 0:
        print(i, "buzz")
    else:
        print(i, "fizz")
# Out:
# 1 fizz
# 2 fizz
# 3 fizz
# 4 fizz
# 5 buzz
# 6 fizz
# 7 fizz
# 8 fizz
# 9 fizz
# 10 buzz
# 11 fizz
# 12 fizz
# 13 fizz
# 14 fizz
# 15 fizzbuzz
# 16 fizz
# 17 fizz
# 18 fizz
# 19 fizz
# 20 buzz
# 21 fizz
# 22 fizz
# 23 fizz
# 24 fizz
# 25 buzz
# 26 fizz
# 27 fizz
# 28 fizz
# 29 fizz
# 30 fizzbuzz
# 31 fizz
# 32 fizz
# 33 fizz
# 34 fizz
# 35 buzz
# 36 fizz
# 37 fizz
# 38 fizz
# 39 fizz
# 40 buzz
# 41 fizz
# 42 fizz
# 43 fizz
# 44 fizz
# 45 fizzbuzz
# 46 fizz
# 47 fizz
# 48 fizz
# 49 fizz
# 50 buzz
# 51 fizz
# 52 fizz
# 53 fizz
# 54 fizz
# 55 buzz
# 56 fizz
# 57 fizz
# 58 fizz
# 59 fizz
# 60 fizzbuzz
# 61 fizz
# 62 fizz
# 63 fizz
# 64 fizz
# 65 buzz
# 66 fizz
# 67 fizz
# 68 fizz
# 69 fizz
# 70 buzz
# 71 fizz
# 72 fizz
# 73 fizz
# 74 fizz
# 75 fizzbuzz
# 76 fizz
# 77 fizz
# 78 fizz
# 79 fizz
# 80 buzz
# 81 fizz
# 82 fizz
# 83 fizz
# 84 fizz
# 85 buzz
# 86 fizz
# 87 fizz
# 88 fizz
# 89 fizz
# 90 fizzbuzz
# 91 fizz
# 92 fizz
# 93 fizz
# 94 fizz
# 95 buzz
# 96 fizz
# 97 fizz
# 98 fizz
# ...
